# %%
# %logstop
# %logstart -rtq ~/.logs/pw.py append
# %matplotlib inline
import matplotlib
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 144

# %%
from static_grader import grader

# %% [markdown]
# # PW Miniproject
# ## Introduction
#
# The objective of this miniproject is to exercise your ability to use basic Python data structures, define functions, and control program flow. We will be using these concepts to perform some fundamental data wrangling tasks such as joining data sets together, splitting data into groups, and aggregating data into summary statistics.
# **Please do not use `pandas` or `numpy` to answer these questions.**
#
# We will be working with medical data from the British NHS on prescription drugs. Since this is real data, it contains many ambiguities that we will need to confront in our analysis. This is commonplace in data science, and is one of the lessons you will learn in this miniproject.

# %% [markdown]
# ## Downloading the data
#
# We first need to download the data we'll be using from Amazon S3:

# %%
# %%bash
# mkdir pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/201701scripts_sample.json.gz -nc -P ./pw-data
# wget http://dataincubator-wqu.s3.amazonaws.com/pwdata/practices.json.gz -nc -P ./pw-data
# Out:
# mkdir: cannot create directory ‘pw-data’: File exists
# File ‘./pw-data/201701scripts_sample.json.gz’ already there; not retrieving.
#
# File ‘./pw-data/practices.json.gz’ already there; not retrieving.

# %% [markdown]
# ## Loading the data
#
# The first step of the project is to read in the data. We will discuss reading and writing various kinds of files later in the course, but the code below should get you started.

# %%
import gzip
import simplejson as json

# %%
with gzip.open('./pw-data/201701scripts_sample.json.gz', 'rb') as f:
    scripts = json.load(f)

with gzip.open('./pw-data/practices.json.gz', 'rb') as f:
    practices = json.load(f)

# %% [markdown]
# This data set comes from Britain's National Health Service. The `scripts` variable is a list of prescriptions issued by NHS doctors. Each prescription is represented by a dictionary with various data fields: `'practice'`, `'bnf_code'`, `'bnf_name'`, `'quantity'`, `'items'`, `'nic'`, and `'act_cost'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %%
type(scripts)
# Out:
# list

# %%
len(scripts)
# Out:
# 382726

# %%
type(scripts[0])
# Out:
# dict

# %% [markdown]
# A [glossary of terms](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10686/Download-glossary-of-terms-for-GP-prescribing---presentation-level/pdf/PLP_Presentation_Level_Glossary_April_2015.pdf/) and [FAQ](http://webarchive.nationalarchives.gov.uk/20180328130852tf_/http://content.digital.nhs.uk/media/10048/FAQs-Practice-Level-Prescribingpdf/pdf/PLP_FAQs_April_2015.pdf/) is available from the NHS regarding the data. Below we supply a data dictionary briefly describing what these fields mean.
#
# | Data field |Description|
# |:----------:|-----------|
# |`'practice'`|Code designating the medical practice issuing the prescription|
# |`'bnf_code'`|British National Formulary drug code|
# |`'bnf_name'`|British National Formulary drug name|
# |`'quantity'`|Number of capsules/quantity of liquid/grams of powder prescribed|
# | `'items'`  |Number of refills (e.g. if `'quantity'` is 30 capsules, 3 `'items'` means 3 bottles of 30 capsules)|
# |  `'nic'`   |Net ingredient cost|
# |`'act_cost'`|Total cost including containers, fees, and discounts|

# %% [markdown]
# The `practices` variable is a list of member medical practices of the NHS. Each practice is represented by a dictionary containing identifying information for the medical practice. Most of the data fields are self-explanatory. Notice the values in the `'code'` field of `practices` match the values in the `'practice'` field of `scripts`.

# %%
practices[:2]
# Out:
# [{'code': 'A81001',
#   'name': 'THE DENSHAM SURGERY',
#   'addr_1': 'THE HEALTH CENTRE',
#   'addr_2': 'LAWSON STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 1HU'},
#  {'code': 'A81002',
#   'name': 'QUEENS PARK MEDICAL CENTRE',
#   'addr_1': 'QUEENS PARK MEDICAL CTR',
#   'addr_2': 'FARRER STREET',
#   'borough': 'STOCKTON ON TEES',
#   'village': 'CLEVELAND',
#   'post_code': 'TS18 2AW'}]

# %% [markdown]
# In the following questions we will ask you to explore this data set. You may need to combine pieces of the data set together in order to answer some questions. Not every element of the data set will be used in answering the questions.

# %% [markdown]
# ## Question 1: summary_statistics
#
# Our beneficiary data (`scripts`) contains quantitative data on the number of items dispensed (`'items'`), the total quantity of item dispensed (`'quantity'`), the net cost of the ingredients (`'nic'`), and the actual cost to the patient (`'act_cost'`). Whenever working with a new data set, it can be useful to calculate summary statistics to develop a feeling for the volume and character of the data. This makes it easier to spot trends and significant features during further stages of analysis.
#
# Calculate the sum, mean, standard deviation, and quartile statistics for each of these quantities. Format your results for each quantity as a list: `[sum, mean, standard deviation, 1st quartile, median, 3rd quartile]`. We'll create a `tuple` with these lists for each quantity as a final result.

# %%
sum([script['items'] for script in scripts])
# Out:
# 4410054

# %%
from statistics import stdev
from math import sqrt

def std(values):
    second_moment = sum([value**2 for value in values])/len(values)
    first_moment = sum(values)/len(values)
    return sqrt(second_moment-first_moment**2)

def quantile(q, values):
    idx = round(q*len(values))
    return sorted(values)[idx]
    
    
def describe(key):
    values = [script[key] for script in scripts]

    total = sum(values)
    avg = sum(values)/len(values)
    s = std(values)   
    q25 = quantile(0.25, values)
    med = quantile(0.50, values)
    q75 = quantile(0.75, values)

    return (total, avg, s, q25, med, q75)

# %%
describe('items')
# Out:
# (4410054, 11.522744731217633, 33.11216633979175, 1, 3, 8)

# %%
summary = [('items', describe('items')),
           ('quantity', describe('quantity')),
           ('nic', describe('nic')),
           ('act_cost', describe('act_cost'))]

# %%
grader.score.pw__summary_statistics(summary)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 2: most_common_item
#
# Often we are not interested only in how the data is distributed in our entire data set, but within particular groups -- for example, how many items of each drug (i.e. `'bnf_name'`) were prescribed? Calculate the total items prescribed for each `'bnf_name'`. What is the most commonly prescribed `'bnf_name'` in our data?
#
# To calculate this, we first need to split our data set into groups corresponding with the different values of `'bnf_name'`. Then we can sum the number of items dispensed within in each group. Finally we can find the largest sum.
#
# We'll use `'bnf_name'` to construct our groups. You should have *5619* unique values for `'bnf_name'`.

# %%
scripts[:2]
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 1,
#   'practice': 'N81013',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 1.95,
#   'act_cost': 1.82,
#   'quantity': 500}]

# %%
bnf_names = set([script['bnf_name'] for script in scripts])
assert(len(bnf_names) == 5619)

# %% [markdown]
# We want to construct "groups" identified by `'bnf_name'`, where each group is a collection of prescriptions (i.e. dictionaries from `scripts`). We'll construct a dictionary called `groups`, using `bnf_names` as the keys. We'll represent a group with a `list`, since we can easily append new members to the group. To split our `scripts` into groups by `'bnf_name'`, we should iterate over `scripts`, appending prescription dictionaries to each group as we encounter them.

# %%
groups = {name: [] for name in bnf_names}
# for script in scripts:
#     # INSERT ...

# %%
for script in scripts:
    groups[script["bnf_name"]].append(script)

# %%
groups['Co-Magaldrox_Susp 195mg/220mg/5ml S/F']
# Out:
# [{'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81013',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'N81029',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'N81088',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 6,
#   'practice': 'A81017',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 20.93,
#   'act_cost': 19.45,
#   'quantity': 3500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'A81034',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.56,
#   'quantity': 1000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 10,
#   'practice': 'P85003',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 29.9,
#   'act_cost': 27.8,
#   'quantity': 5000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 11.96,
#   'act_cost': 11.12,
#   'quantity': 2000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P85601',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P86609',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 3,
#   'practice': 'P86619',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 8.97,
#   'act_cost': 8.34,
#   'quantity': 1500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P81020',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P81025',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P81123',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'P81780',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 6,
#   'practice': 'A84009',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 17.94,
#   'act_cost': 16.68,
#   'quantity': 3000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'A84014',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 3,
#   'practice': 'Y00151',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 11.96,
#   'act_cost': 11.11,
#   'quantity': 2000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'A89010',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 11.96,
#   'act_cost': 11.08,
#   'quantity': 2000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'A89019',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'A89022',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'A89604',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 2.99,
#   'act_cost': 2.78,
#   'quantity': 500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 5,
#   'practice': 'C87005',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 14.95,
#   'act_cost': 13.9,
#   'quantity': 2500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 20,
#   'practice': 'C87017',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 63.15,
#   'act_cost': 58.7,
#   'quantity': 10500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 2,
#   'practice': 'C82642',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 4.19,
#   'act_cost': 4.0,
#   'quantity': 700},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 5,
#   'practice': 'C82667',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 14.95,
#   'act_cost': 13.9,
#   'quantity': 2500},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 3,
#   'practice': 'C83009',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 11.96,
#   'act_cost': 11.11,
#   'quantity': 2000},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 1,
#   'practice': 'C83072',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 5.98,
#   'act_cost': 5.55,
#   'quantity': 1000}]

# %% [markdown]
# Now that we've constructed our groups we should sum up `'items'` in each group and find the `'bnf_name'` with the largest sum. The result, `max_item`, should have the form `[(bnf_name, item total)]`, e.g. `[('Foobar', 2000)]`.

# %%
name,group = list(groups.items())[:1][0]

# %%
ans = max([(sum([member['items'] for member in group]),name)  
     for name,group in groups.items()])[::-1]

# %%
ans
# Out:
# ('Omeprazole_Cap E/C 20mg', 113826)

# %%
max_item = [ans]

# %% [markdown]
# **TIP:** If you are getting an error from the grader below, please make sure your answer conforms to the correct format of `[(bnf_name, item total)]`.

# %%
grader.score.pw__most_common_item(max_item)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# **Challenge:** Write a function that constructs groups as we did above. The function should accept a list of dictionaries (e.g. `scripts` or `practices`) and a tuple of fields to `groupby` (e.g. `('bnf_name')` or `('bnf_name', 'post_code')`) and returns a dictionary of groups. The following questions will require you to aggregate data in groups, so this could be a useful function for the rest of the miniproject.

# %%
bnf_names = {script['bnf_name'] for script in scripts}

def group_by_field(data, fields):
    names = {tuple(item[field] for field in fields) for item in data}
#     return names
    groups = {name: [] for name in names}
    for item in data:
        name = tuple(item[field] for field in fields)
        groups[name].append(item)
    return groups

# %%
result = group_by_field(scripts, ('bnf_name','practice'))

# %%
groups = group_by_field(scripts, ('bnf_name',))
test_max_item =  max([(sum([member['items'] for member in group]),name[0])  
     for name,group in groups.items()])[::-1]

test_max_item = [test_max_item]

# %%
max_item
# Out:
# [('Omeprazole_Cap E/C 20mg', 113826)]

# %%
test_max_item
# Out:
# [('Omeprazole_Cap E/C 20mg', 113826)]

# %%
assert test_max_item == max_item

# %% [markdown]
# ## Question 3: postal_totals
#
# Our data set is broken up among different files. This is typical for tabular data to reduce redundancy. Each table typically contains data about a particular type of event, processes, or physical object. Data on prescriptions and medical practices are in separate files in our case. If we want to find the total items prescribed in each postal code, we will have to _join_ our prescription data (`scripts`) to our clinic data (`practices`).
#
# Find the total items prescribed in each postal code, representing the results as a list of tuples `(post code, total items prescribed)`. Sort your results ascending alphabetically by post code and take only results from the first 100 post codes. Only include post codes if there is at least one prescription from a practice in that post code.
#
# **NOTE:** Some practices have multiple postal codes associated with them. Use the alphabetically first postal code.

# %% [markdown]
# We can join `scripts` and `practices` based on the fact that `'practice'` in `scripts` matches `'code'` in `practices`. However, we must first deal with the repeated values of `'code'` in `practices`. We want the alphabetically first postal codes.

# %%
practice_postal = {}
for practice in practices:
    code = practice["code"]
    
    if code not in practice_postal:
        practice_postal[code] = practice['post_code']
        
    if code in practice_postal:
        practice_postal[code] = min(practice_postal[code], 
                                    practice["post_code"])
        
#     if practice['code'] in practice_postal:
#         practice_postal[practice['code']] = ...
#     else:
#         practice_postal[practice['code']] = ...

# %% [markdown]
# **Challenge:** This is an aggregation of the practice data grouped by practice codes. Write an alternative implementation of the above cell using the `group_by_field` function you defined previously.

# %%
assert practice_postal['K82019'] == 'HP21 8TR'

# %% [markdown]
# Now we can join `practice_postal` to `scripts`.

# %%
joined = scripts[:]
for script in joined:
    script['post_code'] = practice_postal[script['practice']]

# %%
joined[0]
# Out:
# {'bnf_code': '0101010G0AAABAB',
#  'items': 2,
#  'practice': 'N81013',
#  'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#  'nic': 5.98,
#  'act_cost': 5.56,
#  'quantity': 1000,
#  'post_code': 'SK11 6JL'}

# %%
pc_grouped = list(group_by_field(joined, ('post_code',)).items())
pc_grouped[0][1]
# Out:
# [{'bnf_code': '0404000M0AAAAAA',
#   'items': 1,
#   'practice': 'Y04692',
#   'bnf_name': 'Methylphenidate HCl_Tab 10mg',
#   'nic': 10.98,
#   'act_cost': 10.18,
#   'quantity': 60,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0404000M0BDAAAM',
#   'items': 6,
#   'practice': 'Y04692',
#   'bnf_name': 'Concerta_XL Tab 18mg',
#   'nic': 142.45,
#   'act_cost': 132.44,
#   'quantity': 137,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0404000M0BDABAN',
#   'items': 5,
#   'practice': 'Y04692',
#   'bnf_name': 'Concerta_XL Tab 36mg',
#   'nic': 185.37,
#   'act_cost': 172.07,
#   'quantity': 131,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 10,
#   'practice': 'P85003',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 29.9,
#   'act_cost': 27.8,
#   'quantity': 5000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101010R0BCAAAB',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Infacol_Susp 40mg/ml S/F',
#   'nic': 8.13,
#   'act_cost': 7.56,
#   'quantity': 150,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0AAAHAH',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Alginate_Raft-Forming Oral Susp S/F',
#   'nic': 7.8,
#   'act_cost': 7.27,
#   'quantity': 2000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0AAALAL',
#   'items': 105,
#   'practice': 'P85003',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'nic': 462.25,
#   'act_cost': 432.33,
#   'quantity': 45140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0AAAPAP',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Sod Alginate/Pot Bicarb_Tab Chble 500mg',
#   'nic': 12.28,
#   'act_cost': 11.42,
#   'quantity': 240,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEADAJ',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Gaviscon Infant_Sach 2g (Dual Pack) S/F',
#   'nic': 24.1,
#   'act_cost': 22.34,
#   'quantity': 75,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEAIAL',
#   'items': 9,
#   'practice': 'P85003',
#   'bnf_name': 'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#   'nic': 47.06,
#   'act_cost': 43.77,
#   'quantity': 4180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEAQAP',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Gaviscon Advance_Tab Chble Mint(Reckitt)',
#   'nic': 5.94,
#   'act_cost': 5.62,
#   'quantity': 116,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BIAAAH',
#   'items': 14,
#   'practice': 'P85003',
#   'bnf_name': 'Peptac_Liq (Aniseed) S/F',
#   'nic': 25.55,
#   'act_cost': 24.03,
#   'quantity': 6550,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BIABAH',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Peptac_Liq (Peppermint) S/F',
#   'nic': 3.9,
#   'act_cost': 3.64,
#   'quantity': 1000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000N0AAABAB',
#   'items': 40,
#   'practice': 'P85003',
#   'bnf_name': 'Hyoscine Butylbrom_Tab 10mg',
#   'nic': 135.74,
#   'act_cost': 127.35,
#   'quantity': 2534,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000N0BBAAAB',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Buscopan_Tab 10mg',
#   'nic': 21.0,
#   'act_cost': 19.53,
#   'quantity': 392,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000P0AAABAB',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Mebeverine HCl_Tab 135mg',
#   'nic': 55.74,
#   'act_cost': 51.93,
#   'quantity': 1068,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103010T0AAAAAA',
#   'items': 44,
#   'practice': 'P85003',
#   'bnf_name': 'Ranitidine HCl_Tab 150mg',
#   'nic': 43.95,
#   'act_cost': 42.83,
#   'quantity': 2126,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103010T0AAACAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Ranitidine HCl_Tab 300mg',
#   'nic': 3.73,
#   'act_cost': 3.59,
#   'quantity': 88,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103010T0AAAEAE',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Ranitidine HCl_Oral Soln 75mg/5ml S/F',
#   'nic': 4.18,
#   'act_cost': 4.09,
#   'quantity': 200,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Esomeprazole_Tab E/C 20mg',
#   'nic': 5.3,
#   'act_cost': 4.93,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAABAB',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Esomeprazole_Tab E/C 40mg',
#   'nic': 23.17,
#   'act_cost': 21.54,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAAFAF',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Esomeprazole_Cap E/C 20mg',
#   'nic': 23.8,
#   'act_cost': 22.1,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAAGAG',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Esomeprazole_Cap E/C 40mg',
#   'nic': 11.88,
#   'act_cost': 11.04,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAAAAA',
#   'items': 183,
#   'practice': 'P85003',
#   'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#   'nic': 210.47,
#   'act_cost': 198.11,
#   'quantity': 5308,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAABAB',
#   'items': 15,
#   'practice': 'P85003',
#   'bnf_name': 'Lansoprazole_Cap 15mg (E/C Gran)',
#   'nic': 12.6,
#   'act_cost': 11.85,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAAGAG',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Lansoprazole_Orodisper Tab 15mg',
#   'nic': 14.7,
#   'act_cost': 13.7,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAAHAH',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#   'nic': 6.84,
#   'act_cost': 6.36,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0BBAEAH',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Zoton_FasTab Tab 30mg',
#   'nic': 5.5,
#   'act_cost': 5.1,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAAAA',
#   'items': 462,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Cap E/C 20mg',
#   'nic': 457.09,
#   'act_cost': 430.18,
#   'quantity': 14063,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAEAE',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Cap E/C 40mg',
#   'nic': 27.0,
#   'act_cost': 25.08,
#   'quantity': 252,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAFAF',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Cap E/C 10mg',
#   'nic': 5.34,
#   'act_cost': 5.02,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAMAM',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#   'nic': 7.75,
#   'act_cost': 7.19,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAANAN',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Tab Disper 20mg (E/C Pellets)',
#   'nic': 34.8,
#   'act_cost': 32.25,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AABDBD',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Omeprazole_Tab E/C 20mg',
#   'nic': 76.62,
#   'act_cost': 71.38,
#   'quantity': 357,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050R0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Pantoprazole_Tab E/C 40mg',
#   'nic': 1.12,
#   'act_cost': 1.05,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050R0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Pantoprazole_Tab E/C 20mg',
#   'nic': 0.95,
#   'act_cost': 0.89,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050T0AAAAAA',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Rabeprazole Sod_Tab E/C 10mg',
#   'nic': 9.38,
#   'act_cost': 8.77,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050T0AAABAB',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Rabeprazole Sod_Tab E/C 20mg',
#   'nic': 8.85,
#   'act_cost': 8.25,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0104020L0AAAAAA',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Loperamide HCl_Cap 2mg',
#   'nic': 11.84,
#   'act_cost': 11.31,
#   'quantity': 370,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010B0BBAFAS',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Asacol_MR Tab E/C 800mg',
#   'nic': 36.6,
#   'act_cost': 34.0,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010B0BHAAAR',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Mezavant XL_Tab G/R 1.2g',
#   'nic': 42.95,
#   'act_cost': 39.77,
#   'quantity': 60,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010E0AAAAAA',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Sulfasalazine_Tab 500mg',
#   'nic': 53.56,
#   'act_cost': 50.08,
#   'quantity': 814,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010E0AAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Sulfasalazine_Tab E/C 500mg',
#   'nic': 31.95,
#   'act_cost': 29.8,
#   'quantity': 320,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010E0BBABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Salazopyrin-En_Tab 500mg',
#   'nic': 8.43,
#   'act_cost': 7.82,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106010E0AAADAD',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Ispag Husk_Gran Eff Sach 3.5g G/F S/F',
#   'nic': 44.88,
#   'act_cost': 41.79,
#   'quantity': 495,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106010E0AAAHAH',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Ispag Husk_Gran Eff Sach 3.5g Orange S/F',
#   'nic': 16.32,
#   'act_cost': 15.18,
#   'quantity': 180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020C0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Bisacodyl_Tab E/C 5mg',
#   'nic': 5.23,
#   'act_cost': 4.97,
#   'quantity': 160,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020I0AAAKAK',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Docusate Sod_Cap 100mg',
#   'nic': 40.41,
#   'act_cost': 37.6,
#   'quantity': 580,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020M0AAACAC',
#   'items': 43,
#   'practice': 'P85003',
#   'bnf_name': 'Senna_Tab 7.5mg',
#   'nic': 82.65,
#   'act_cost': 77.95,
#   'quantity': 2466,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020M0AAATAT',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Senna_Oral Soln 7.5mg/5ml S/F',
#   'nic': 4.76,
#   'act_cost': 4.42,
#   'quantity': 500,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040G0AAAAAA',
#   'items': 32,
#   'practice': 'P85003',
#   'bnf_name': 'Lactulose_Soln 3.1g-3.7g/5ml',
#   'nic': 51.89,
#   'act_cost': 50.83,
#   'quantity': 10300,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0AAAAAA',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Macrogol_Co Oral Pdr Sach S/F',
#   'nic': 61.22,
#   'act_cost': 57.32,
#   'quantity': 430,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBAAAA',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Movicol_Pdr Sach 13.8g (Lem & Lim)',
#   'nic': 33.44,
#   'act_cost': 31.1,
#   'quantity': 130,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBAIAB',
#   'items': 21,
#   'practice': 'P85003',
#   'bnf_name': 'Movicol Plain_Paed Pdr Sach 6.9g',
#   'nic': 110.09,
#   'act_cost': 102.48,
#   'quantity': 754,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBAJAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Movicol_Paed Pdr Sach 6.9g (Choc)',
#   'nic': 4.38,
#   'act_cost': 4.07,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BCACAA',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Laxido_Oral Pdr Sach (Orange) S/F',
#   'nic': 21.36,
#   'act_cost': 20.14,
#   'quantity': 150,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106070B0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Linaclotide_Cap 290mcg',
#   'nic': 75.12,
#   'act_cost': 69.57,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107010Z0BCAAAE',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Anusol_Crm',
#   'nic': 4.9,
#   'act_cost': 4.56,
#   'quantity': 46,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107010Z0BCABAF',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Anusol_Oint',
#   'nic': 4.9,
#   'act_cost': 4.56,
#   'quantity': 50,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020J0AAAEAE',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Cinchocaine HCl/Hydrocort_Oint 0.5%/0.5%',
#   'nic': 24.91,
#   'act_cost': 23.1,
#   'quantity': 90,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020J0BCAAAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Anusol HC_Suppos',
#   'nic': 3.48,
#   'act_cost': 3.25,
#   'quantity': 24,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020J0BCABAC',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Anusol HC_Oint',
#   'nic': 9.96,
#   'act_cost': 9.27,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020J0BEAAAE',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Proctosedyl_Oint',
#   'nic': 10.34,
#   'act_cost': 9.58,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020P0BCAAAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Scheriproct_Oint',
#   'nic': 8.82,
#   'act_cost': 8.2,
#   'quantity': 90,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020P0BCABAD',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Scheriproct_Suppos',
#   'nic': 4.14,
#   'act_cost': 3.87,
#   'quantity': 36,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0201010F0AAADAD',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Digoxin_Tab 62.5mcg',
#   'nic': 1.82,
#   'act_cost': 1.7,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0201010F0AAAEAE',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Digoxin_Tab 125mcg',
#   'nic': 12.74,
#   'act_cost': 11.88,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010B0AAABAB',
#   'items': 64,
#   'practice': 'P85003',
#   'bnf_name': 'Bendroflumethiazide_Tab 2.5mg',
#   'nic': 45.54,
#   'act_cost': 42.95,
#   'quantity': 1932,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010B0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Bendroflumethiazide_Tab 5mg',
#   'nic': 1.72,
#   'act_cost': 1.62,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010P0AAAAAA',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Indapamide_Tab 2.5mg',
#   'nic': 3.21,
#   'act_cost': 3.01,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202020D0AAAEAE',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Bumetanide_Tab 1mg',
#   'nic': 18.45,
#   'act_cost': 17.73,
#   'quantity': 315,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202020D0AAAFAF',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Bumetanide_Tab 5mg',
#   'nic': 3.49,
#   'act_cost': 3.34,
#   'quantity': 14,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202020L0AABBBB',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Furosemide_Tab 20mg',
#   'nic': 10.4,
#   'act_cost': 9.89,
#   'quantity': 399,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202020L0AABDBD',
#   'items': 27,
#   'practice': 'P85003',
#   'bnf_name': 'Furosemide_Tab 40mg',
#   'nic': 30.36,
#   'act_cost': 28.44,
#   'quantity': 1232,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202030S0AAATAT',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Spironol_Tab 25mg',
#   'nic': 1.3,
#   'act_cost': 1.22,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202030S0AAAVAV',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Spironol_Tab 100mg',
#   'nic': 10.0,
#   'act_cost': 9.29,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202030X0AAAAAA',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Eplerenone_Tab 25mg',
#   'nic': 16.56,
#   'act_cost': 15.6,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202030X0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Eplerenone_Tab 50mg',
#   'nic': 5.37,
#   'act_cost': 4.98,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202040B0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Co-Amilofruse_Tab 5mg/40mg',
#   'nic': 2.42,
#   'act_cost': 2.25,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0203020D0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Amiodarone HCl_Tab 200mg',
#   'nic': 1.91,
#   'act_cost': 1.78,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000ABAAAAAA',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Nebivolol_Tab 5mg',
#   'nic': 10.0,
#   'act_cost': 9.36,
#   'quantity': 224,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000ABAAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Nebivolol_Tab 2.5mg',
#   'nic': 31.52,
#   'act_cost': 29.19,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000E0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Atenolol_Oral Soln 25mg/5ml S/F',
#   'nic': 11.18,
#   'act_cost': 10.36,
#   'quantity': 600,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000E0AAABAB',
#   'items': 16,
#   'practice': 'P85003',
#   'bnf_name': 'Atenolol_Tab 50mg',
#   'nic': 10.94,
#   'act_cost': 10.73,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000E0AAACAC',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Atenolol_Tab 100mg',
#   'nic': 3.0,
#   'act_cost': 2.83,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000E0AAAGAG',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Atenolol_Tab 25mg',
#   'nic': 4.97,
#   'act_cost': 4.69,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000H0AAAAAA',
#   'items': 16,
#   'practice': 'P85003',
#   'bnf_name': 'Bisoprolol Fumar_Tab 5mg',
#   'nic': 12.0,
#   'act_cost': 11.31,
#   'quantity': 448,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000H0AAABAB',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Bisoprolol Fumar_Tab 10mg',
#   'nic': 3.95,
#   'act_cost': 3.72,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000H0AAAJAJ',
#   'items': 45,
#   'practice': 'P85003',
#   'bnf_name': 'Bisoprolol Fumar_Tab 2.5mg',
#   'nic': 38.42,
#   'act_cost': 36.23,
#   'quantity': 1379,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000H0AAAKAK',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Bisoprolol Fumar_Tab 3.75mg',
#   'nic': 4.42,
#   'act_cost': 4.25,
#   'quantity': 119,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000H0AAAMAM',
#   'items': 25,
#   'practice': 'P85003',
#   'bnf_name': 'Bisoprolol Fumar_Tab 1.25mg',
#   'nic': 21.75,
#   'act_cost': 20.45,
#   'quantity': 700,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000I0AAADAD',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Labetalol HCl_Tab 200mg',
#   'nic': 17.54,
#   'act_cost': 16.26,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000K0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Metoprolol Tart_Tab 50mg',
#   'nic': 2.1,
#   'act_cost': 1.96,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000R0AAAAAA',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Propranolol HCl_Cap 80mg M/R',
#   'nic': 44.56,
#   'act_cost': 41.79,
#   'quantity': 252,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000R0AAAHAH',
#   'items': 29,
#   'practice': 'P85003',
#   'bnf_name': 'Propranolol HCl_Tab 10mg',
#   'nic': 46.9,
#   'act_cost': 43.88,
#   'quantity': 1582,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000R0AAAJAJ',
#   'items': 16,
#   'practice': 'P85003',
#   'bnf_name': 'Propranolol HCl_Tab 40mg',
#   'nic': 16.18,
#   'act_cost': 15.77,
#   'quantity': 532,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0204000R0AAAKAK',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Propranolol HCl_Tab 80mg',
#   'nic': 3.83,
#   'act_cost': 3.68,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '020400080AAAFAF',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Carvedilol_Tab 6.25mg',
#   'nic': 0.91,
#   'act_cost': 0.85,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205020H0AAADAD',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Methyldopa_Tab 250mg',
#   'nic': 16.11,
#   'act_cost': 14.93,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205020M0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Moxonidine_Tab 200mcg',
#   'nic': 1.42,
#   'act_cost': 1.33,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205040D0AAAAAA',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Doxazosin Mesil_Tab 1mg',
#   'nic': 11.36,
#   'act_cost': 10.65,
#   'quantity': 448,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205040D0AAABAB',
#   'items': 22,
#   'practice': 'P85003',
#   'bnf_name': 'Doxazosin Mesil_Tab 2mg',
#   'nic': 25.9,
#   'act_cost': 24.25,
#   'quantity': 980,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205040D0AAACAC',
#   'items': 23,
#   'practice': 'P85003',
#   'bnf_name': 'Doxazosin Mesil_Tab 4mg',
#   'nic': 31.08,
#   'act_cost': 29.06,
#   'quantity': 1036,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205040D0AAAQAQ',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Doxazosin Mesil_Tab 4mg M/R',
#   'nic': 80.0,
#   'act_cost': 74.2,
#   'quantity': 448,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205040D0AAARAR',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Doxazosin Mesil_Tab 8mg M/R',
#   'nic': 129.74,
#   'act_cost': 120.24,
#   'quantity': 364,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051I0AAADAD',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Enalapril Mal_Tab 20mg',
#   'nic': 3.92,
#   'act_cost': 3.68,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051K0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Lisinopril/Hydchloroth_Tab 20mg/12.5mg',
#   'nic': 1.82,
#   'act_cost': 1.7,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051L0AAAAAA',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Lisinopril_Tab 2.5mg',
#   'nic': 4.26,
#   'act_cost': 4.02,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051L0AAABAB',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Lisinopril_Tab 5mg',
#   'nic': 3.65,
#   'act_cost': 3.42,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051L0AAACAC',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Lisinopril_Tab 10mg',
#   'nic': 9.48,
#   'act_cost': 8.92,
#   'quantity': 336,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051L0AAADAD',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Lisinopril_Tab 20mg',
#   'nic': 6.64,
#   'act_cost': 6.23,
#   'quantity': 224,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051M0AAABAB',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Perindopril Erbumine_Tab 4mg',
#   'nic': 4.36,
#   'act_cost': 4.09,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051M0AAAFAF',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Perindopril Erbumine_Tab 8mg',
#   'nic': 1.3,
#   'act_cost': 1.22,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAAAAA',
#   'items': 21,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Cap 1.25mg',
#   'nic': 28.77,
#   'act_cost': 26.89,
#   'quantity': 588,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAABAB',
#   'items': 57,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Cap 2.5mg',
#   'nic': 103.1,
#   'act_cost': 96.24,
#   'quantity': 1659,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAACAC',
#   'items': 57,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Cap 5mg',
#   'nic': 66.12,
#   'act_cost': 61.92,
#   'quantity': 1596,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAADAD',
#   'items': 83,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Cap 10mg',
#   'nic': 101.2,
#   'act_cost': 94.71,
#   'quantity': 2464,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAAKAK',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Tab 1.25mg',
#   'nic': 3.3,
#   'act_cost': 3.08,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAALAL',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Tab 2.5mg',
#   'nic': 3.45,
#   'act_cost': 3.23,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAAMAM',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Tab 5mg',
#   'nic': 2.94,
#   'act_cost': 2.76,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205051R0AAANAN',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Ramipril_Tab 10mg',
#   'nic': 1.24,
#   'act_cost': 1.16,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052A0AAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Irbesartan/Hydchloroth_Tab 300mg/12.5mg',
#   'nic': 4.0,
#   'act_cost': 3.73,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052A0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Irbesartan/Hydchloroth_Tab 300mg/25mg',
#   'nic': 13.24,
#   'act_cost': 12.28,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052B0AAAAAA',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Olmesartan Medoxomil_Tab 10mg',
#   'nic': 32.85,
#   'act_cost': 30.45,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052B0AAABAB',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Olmesartan Medoxomil_Tab 20mg',
#   'nic': 103.6,
#   'act_cost': 96.0,
#   'quantity': 224,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052B0AAACAC',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Olmesartan Medoxomil_Tab 40mg',
#   'nic': 192.5,
#   'act_cost': 178.34,
#   'quantity': 308,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052C0AAABAB',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Candesartan Cilexetil_Tab 4mg',
#   'nic': 13.2,
#   'act_cost': 12.25,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052C0AAACAC',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Candesartan Cilexetil_Tab 8mg',
#   'nic': 3.19,
#   'act_cost': 3.1,
#   'quantity': 91,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052C0AAAHAH',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Candesartan Cilexetil_Tab 32mg',
#   'nic': 1.59,
#   'act_cost': 1.48,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052I0AAAAAA',
#   'items': 15,
#   'practice': 'P85003',
#   'bnf_name': 'Irbesartan_Tab 75mg',
#   'nic': 16.49,
#   'act_cost': 15.45,
#   'quantity': 476,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052I0AAABAB',
#   'items': 62,
#   'practice': 'P85003',
#   'bnf_name': 'Irbesartan_Tab 150mg',
#   'nic': 77.35,
#   'act_cost': 72.38,
#   'quantity': 1820,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052I0AAACAC',
#   'items': 111,
#   'practice': 'P85003',
#   'bnf_name': 'Irbesartan_Tab 300mg',
#   'nic': 202.12,
#   'act_cost': 188.49,
#   'quantity': 3472,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052N0AAAAAA',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Losartan Pot_Tab 25mg',
#   'nic': 2.0,
#   'act_cost': 1.99,
#   'quantity': 70,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052N0AAABAB',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Losartan Pot_Tab 50mg',
#   'nic': 12.9,
#   'act_cost': 12.09,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052N0AAADAD',
#   'items': 38,
#   'practice': 'P85003',
#   'bnf_name': 'Losartan Pot_Tab 100mg',
#   'nic': 39.6,
#   'act_cost': 37.13,
#   'quantity': 1120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052P0AAAAAA',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Losartan Pot/Hydchloroth_Tab 50mg/12.5mg',
#   'nic': 5.24,
#   'act_cost': 4.9,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052P0AAABAB',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Losartan Pot/Hydchloroth_Tab 100mg/25mg',
#   'nic': 9.3,
#   'act_cost': 8.68,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052Q0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Telmisartan_Tab 40mg',
#   'nic': 2.36,
#   'act_cost': 2.2,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052Q0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Telmisartan_Tab 20mg',
#   'nic': 2.02,
#   'act_cost': 1.89,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052V0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Valsartan_Cap 160mg',
#   'nic': 10.4,
#   'act_cost': 9.65,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0205052X0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Valsartan/Hydchloroth_Tab 160mg/25mg',
#   'nic': 10.44,
#   'act_cost': 9.68,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010F0AACICI',
#   'items': 25,
#   'practice': 'P85003',
#   'bnf_name': 'Glyceryl Trinit_Sub P/Spy 400mcg (180D)',
#   'nic': 48.33,
#   'act_cost': 45.05,
#   'quantity': 27,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Tab 10mg',
#   'nic': 6.8,
#   'act_cost': 6.52,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAACAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Tab 20mg',
#   'nic': 9.01,
#   'act_cost': 8.68,
#   'quantity': 148,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAAEAE',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Tab 60mg M/R',
#   'nic': 63.0,
#   'act_cost': 58.61,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAAHAH',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Cap 25mg M/R',
#   'nic': 13.6,
#   'act_cost': 12.64,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAAPAP',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Cap 40mg M/R',
#   'nic': 13.04,
#   'act_cost': 12.1,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0AAATAT',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Isosorbide Mononit_Tab 25mg M/R',
#   'nic': 6.75,
#   'act_cost': 6.26,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206010K0CNAAAE',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Monomil XL_Tab 60mg',
#   'nic': 47.12,
#   'act_cost': 43.88,
#   'quantity': 378,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020A0AAAAAA',
#   'items': 100,
#   'practice': 'P85003',
#   'bnf_name': 'Amlodipine_Tab 5mg',
#   'nic': 78.84,
#   'act_cost': 74.22,
#   'quantity': 3024,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020A0AAABAB',
#   'items': 100,
#   'practice': 'P85003',
#   'bnf_name': 'Amlodipine_Tab 10mg',
#   'nic': 82.37,
#   'act_cost': 78.0,
#   'quantity': 2919,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020C0BFAGAU',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Adizem-XL_Cap 120mg',
#   'nic': 9.14,
#   'act_cost': 8.47,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020F0AAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Felodipine_Tab 5mg M/R',
#   'nic': 8.42,
#   'act_cost': 7.82,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020F0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Felodipine_Tab 10mg M/R',
#   'nic': 11.32,
#   'act_cost': 10.5,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020F0AAADAD',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Felodipine_Tab 2.5mg M/R',
#   'nic': 25.24,
#   'act_cost': 23.39,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020K0AAAAAA',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Lacidipine_Tab 2mg',
#   'nic': 31.95,
#   'act_cost': 29.74,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020K0AAABAB',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Lacidipine_Tab 4mg',
#   'nic': 8.68,
#   'act_cost': 8.09,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020L0AAAAAA',
#   'items': 28,
#   'practice': 'P85003',
#   'bnf_name': 'Lercanidipine HCl_Tab 10mg',
#   'nic': 137.17,
#   'act_cost': 127.33,
#   'quantity': 812,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020L0AAABAB',
#   'items': 10,
#   'practice': 'P85003',
#   'bnf_name': 'Lercanidipine HCl_Tab 20mg',
#   'nic': 61.4,
#   'act_cost': 56.97,
#   'quantity': 280,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020R0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Nifedipine_Cap 5mg',
#   'nic': 32.17,
#   'act_cost': 29.91,
#   'quantity': 140,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206020R0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Nifedipine_Cap 10mg',
#   'nic': 3.85,
#   'act_cost': 3.68,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030N0AAAAAA',
#   'items': 15,
#   'practice': 'P85003',
#   'bnf_name': 'Nicorandil_Tab 10mg',
#   'nic': 15.07,
#   'act_cost': 15.13,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030N0AAABAB',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Nicorandil_Tab 20mg',
#   'nic': 12.72,
#   'act_cost': 11.81,
#   'quantity': 180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030Y0AAAAAA',
#   'items': 12,
#   'practice': 'P85003',
#   'bnf_name': 'Ivabradine_Tab 5mg',
#   'nic': 421.8,
#   'act_cost': 390.93,
#   'quantity': 588,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030Y0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Ivabradine_Tab 7.5mg',
#   'nic': 40.17,
#   'act_cost': 37.2,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030Z0AAAAAA',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Ranolazine_Tab 375mg M/R',
#   'nic': 293.88,
#   'act_cost': 272.14,
#   'quantity': 360,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030Z0AAABAB',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Ranolazine_Tab 500mg M/R',
#   'nic': 146.94,
#   'act_cost': 136.07,
#   'quantity': 180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206030Z0AAACAC',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Ranolazine_Tab 750mg M/R',
#   'nic': 97.96,
#   'act_cost': 90.71,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206040AEAAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Naftidrofuryl Oxal_Cap 100mg',
#   'nic': 4.41,
#   'act_cost': 4.09,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0206040AHAAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Oxerutins_Cap 250mg',
#   'nic': 12.94,
#   'act_cost': 12.09,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0208020V0AAAAAA',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Warfarin Sod_Tab 1mg',
#   'nic': 14.17,
#   'act_cost': 13.41,
#   'quantity': 559,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0208020V0AAADAD',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Warfarin Sod_Tab 5mg',
#   'nic': 5.46,
#   'act_cost': 5.13,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0208020Y0AAACAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Rivaroxaban_Tab 20mg',
#   'nic': 151.2,
#   'act_cost': 140.01,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0208020Z0AAAAAA',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Apixaban_Tab 2.5mg',
#   'nic': 220.4,
#   'act_cost': 204.29,
#   'quantity': 232,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0208020Z0AAABAB',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Apixaban_Tab 5mg',
#   'nic': 319.2,
#   'act_cost': 295.54,
#   'quantity': 336,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000A0AAABAB',
#   'items': 110,
#   'practice': 'P85003',
#   'bnf_name': 'Aspirin Disper_Tab 75mg',
#   'nic': 76.91,
#   'act_cost': 73.36,
#   'quantity': 3075,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000A0AAAJAJ',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Aspirin_Tab 75mg',
#   'nic': 12.43,
#   'act_cost': 11.64,
#   'quantity': 308,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000A0AAAKAK',
#   'items': 34,
#   'practice': 'P85003',
#   'bnf_name': 'Aspirin_Tab E/C 75mg',
#   'nic': 31.2,
#   'act_cost': 29.8,
#   'quantity': 1015,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000C0AAAAAA',
#   'items': 51,
#   'practice': 'P85003',
#   'bnf_name': 'Clopidogrel_Tab 75mg',
#   'nic': 68.23,
#   'act_cost': 64.19,
#   'quantity': 1436,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000V0BBAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Asasantin Ret_Cap',
#   'nic': 19.68,
#   'act_cost': 18.24,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0209000Z0AAAAAA',
#   'items': 15,
#   'practice': 'P85003',
#   'bnf_name': 'Ticagrelor_Tab 90mg',
#   'nic': 778.05,
#   'act_cost': 720.57,
#   'quantity': 798,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0211000P0AAACAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Tranexamic Acid_Tab 500mg',
#   'nic': 10.58,
#   'act_cost': 9.94,
#   'quantity': 150,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000AAAAAAAA',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Rosuvastatin Calc_Tab 10mg',
#   'nic': 234.39,
#   'act_cost': 217.15,
#   'quantity': 364,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000AAAAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Rosuvastatin Calc_Tab 20mg',
#   'nic': 78.06,
#   'act_cost': 72.29,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000AAAAACAC',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Rosuvastatin Calc_Tab 40mg',
#   'nic': 29.68,
#   'act_cost': 27.93,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000AAAAADAD',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Rosuvastatin Calc_Tab 5mg',
#   'nic': 18.03,
#   'act_cost': 16.7,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000ABAAAAAA',
#   'items': 15,
#   'practice': 'P85003',
#   'bnf_name': 'EPA/DHA_Cap 460mg/380mg',
#   'nic': 370.24,
#   'act_cost': 342.94,
#   'quantity': 728,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000ABBBAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Omacor_Cap',
#   'nic': 85.43,
#   'act_cost': 79.21,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000B0AAAAAA',
#   'items': 39,
#   'practice': 'P85003',
#   'bnf_name': 'Atorvastatin_Tab 10mg',
#   'nic': 34.32,
#   'act_cost': 32.26,
#   'quantity': 1092,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000B0AAABAB',
#   'items': 243,
#   'practice': 'P85003',
#   'bnf_name': 'Atorvastatin_Tab 20mg',
#   'nic': 263.93,
#   'act_cost': 247.94,
#   'quantity': 7245,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000B0AAACAC',
#   'items': 81,
#   'practice': 'P85003',
#   'bnf_name': 'Atorvastatin_Tab 40mg',
#   'nic': 95.5,
#   'act_cost': 89.51,
#   'quantity': 2247,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000B0AAADAD',
#   'items': 53,
#   'practice': 'P85003',
#   'bnf_name': 'Atorvastatin_Tab 80mg',
#   'nic': 99.22,
#   'act_cost': 92.71,
#   'quantity': 1470,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000D0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Bezafibrate_Tab 200mg',
#   'nic': 1.22,
#   'act_cost': 1.24,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000D0AAABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Bezafibrate_Tab 400mg M/R',
#   'nic': 7.63,
#   'act_cost': 7.08,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000L0AAAAAA',
#   'items': 17,
#   'practice': 'P85003',
#   'bnf_name': 'Ezetimibe_Tab 10mg',
#   'nic': 420.97,
#   'act_cost': 390.33,
#   'quantity': 448,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000P0AAADAD',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Fenofibrate_Cap 267mg (Micronised)',
#   'nic': 4.88,
#   'act_cost': 4.97,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000P0AAAEAE',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Fenofibrate_Tab 160mg (Micronised)',
#   'nic': 20.07,
#   'act_cost': 18.62,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000X0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Pravastatin Sod_Tab 10mg',
#   'nic': 1.74,
#   'act_cost': 1.64,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000X0AAABAB',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Pravastatin Sod_Tab 20mg',
#   'nic': 2.08,
#   'act_cost': 1.95,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000X0AAADAD',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Pravastatin Sod_Tab 40mg',
#   'nic': 2.52,
#   'act_cost': 2.36,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000Y0AAAAAA',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Simvastatin_Tab 10mg',
#   'nic': 2.04,
#   'act_cost': 1.91,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000Y0AAABAB',
#   'items': 70,
#   'practice': 'P85003',
#   'bnf_name': 'Simvastatin_Tab 20mg',
#   'nic': 54.2,
#   'act_cost': 51.64,
#   'quantity': 1897,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000Y0AAADAD',
#   'items': 206,
#   'practice': 'P85003',
#   'bnf_name': 'Simvastatin_Tab 40mg',
#   'nic': 184.04,
#   'act_cost': 172.93,
#   'quantity': 5992,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0212000Y0AAAHAH',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Simvastatin_Tab 80mg',
#   'nic': 10.44,
#   'act_cost': 9.74,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0AAAPAP',
#   'items': 123,
#   'practice': 'P85003',
#   'bnf_name': 'Salbutamol_Inha 100mcg (200 D) CFF',
#   'nic': 195.0,
#   'act_cost': 182.05,
#   'quantity': 130,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0AAAXAX',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Salbutamol_Inh Soln 2.5mg/2.5ml Ud',
#   'nic': 36.29,
#   'act_cost': 33.65,
#   'quantity': 380,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0AABDBD',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Salbutamol_Inh Soln 5mg/2.5ml Ud',
#   'nic': 42.02,
#   'act_cost': 38.94,
#   'quantity': 220,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0AABUBU',
#   'items': 23,
#   'practice': 'P85003',
#   'bnf_name': 'Salbutamol_Inha B/A 100mcg (200 D) CFF',
#   'nic': 144.9,
#   'act_cost': 134.43,
#   'quantity': 23,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0BEAIAP',
#   'items': 58,
#   'practice': 'P85003',
#   'bnf_name': 'Ventolin_Evohaler 100mcg (200 D)',
#   'nic': 90.0,
#   'act_cost': 84.04,
#   'quantity': 60,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0BIAGBU',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Salamol E-Breathe_Inh 100mcg (200 D) CFF',
#   'nic': 31.5,
#   'act_cost': 29.22,
#   'quantity': 5,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011R0BWAABZ',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Easyhaler_Salbutamol Sulf 100mcg (200D)',
#   'nic': 3.31,
#   'act_cost': 3.08,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011V0AAALAL',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Terbut Sulf_B/A Inha 500mcg (100 D)',
#   'nic': 20.76,
#   'act_cost': 19.26,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301011V0BBAMAL',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Bricanyl_Turbohaler 500mcg (100 D)',
#   'nic': 13.84,
#   'act_cost': 12.84,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020I0AAANAN',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Ipratrop Brom_Inha 20mcg (200 D) CFF',
#   'nic': 11.12,
#   'act_cost': 10.32,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0AAAAAA',
#   'items': 14,
#   'practice': 'P85003',
#   'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg + Dev',
#   'nic': 488.18,
#   'act_cost': 452.11,
#   'quantity': 420,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0AAABAB',
#   'items': 7,
#   'practice': 'P85003',
#   'bnf_name': 'Tiotropium_Pdr For Inh Cap 18mcg',
#   'nic': 234.5,
#   'act_cost': 217.18,
#   'quantity': 210,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0AAACAC',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Tiotropium_Inha 2.5mcg (60D) CFF + Dev',
#   'nic': 23.0,
#   'act_cost': 21.3,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0BBAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Spiriva_Pdr For Inh Cap 18mcg+HandiHaler',
#   'nic': 34.87,
#   'act_cost': 32.29,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0BBABAB',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Spiriva_Pdr For Inh Cap 18mcg',
#   'nic': 33.5,
#   'act_cost': 31.03,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020Q0BBACAC',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Spiriva Respimat_Inha 2.5mcg (60D) + Dev',
#   'nic': 69.0,
#   'act_cost': 63.91,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301020S0BBAAAA',
#   'items': 10,
#   'practice': 'P85003',
#   'bnf_name': 'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#   'nic': 275.0,
#   'act_cost': 254.71,
#   'quantity': 300,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301030C0AAAEAE',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Aminophylline Hydrate_Tab 225mg M/R',
#   'nic': 3.6,
#   'act_cost': 3.45,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301030C0BCAAAE',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Phyllocontin Continus_Tab 225mg',
#   'nic': 2.4,
#   'act_cost': 2.23,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301040W0BBAAAA',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Anoro Ellipta_Inha 55mcg/22mcg (30D)',
#   'nic': 162.5,
#   'act_cost': 150.5,
#   'quantity': 5,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0301040X0AAAAAA',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Tiotropium/Olodaterol_Inha2.5/2.5mcg 60D',
#   'nic': 32.5,
#   'act_cost': 30.1,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0AABEBE',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Beclomet Diprop_Inha 50mcg (200 D) CFF',
#   'nic': 3.7,
#   'act_cost': 3.44,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0AABFBF',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#   'nic': 24.63,
#   'act_cost': 22.83,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0AABXBX',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Beclomet Diprop/Formoterol_Inh100/6(120D',
#   'nic': 381.16,
#   'act_cost': 353.02,
#   'quantity': 13,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BJABBF',
#   'items': 13,
#   'practice': 'P85003',
#   'bnf_name': 'Qvar 100_Inha 100mcg (200 D)',
#   'nic': 258.15,
#   'act_cost': 239.14,
#   'quantity': 15,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BJAFBH',
#   'items': 11,
#   'practice': 'P85003',
#   'bnf_name': 'Qvar 100 E-Breathe_Inha 100mcg (200 D)',
#   'nic': 186.45,
#   'act_cost': 172.74,
#   'quantity': 11,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BPAABE',
#   'items': 41,
#   'practice': 'P85003',
#   'bnf_name': 'Clenil Modulite_Inha 50mcg (200D)',
#   'nic': 151.7,
#   'act_cost': 140.95,
#   'quantity': 41,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BPABBF',
#   'items': 60,
#   'practice': 'P85003',
#   'bnf_name': 'Clenil Modulite_Inha 100mcg (200D)',
#   'nic': 460.04,
#   'act_cost': 426.63,
#   'quantity': 62,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BPACBV',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Clenil Modulite_Inha 200mcg (200D)',
#   'nic': 129.36,
#   'act_cost': 119.85,
#   'quantity': 8,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BPADBW',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Clenil Modulite_Inha 250mcg (200D)',
#   'nic': 48.87,
#   'act_cost': 45.28,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BQAABX',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Fostair_Inh 100mcg/6mcg (120D) CFF',
#   'nic': 175.92,
#   'act_cost': 162.93,
#   'quantity': 6,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BQABBZ',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Fostair_Inh 200mcg/6mcg (120D) CFF',
#   'nic': 146.6,
#   'act_cost': 135.78,
#   'quantity': 5,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000C0BRAABY',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Fostair NEXThaler_Inh 100mcg/6mcg (120D)',
#   'nic': 87.96,
#   'act_cost': 81.47,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000K0AAALAL',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 100/6(120D',
#   'nic': 66.0,
#   'act_cost': 61.12,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000K0AAAMAM',
#   'items': 8,
#   'practice': 'P85003',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 200/6(120D',
#   'nic': 342.0,
#   'act_cost': 316.71,
#   'quantity': 9,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000K0AAAUAU',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Budesonide/Formoterol Inh B/A 400/12(60D',
#   'nic': 114.0,
#   'act_cost': 105.56,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000K0BDABAM',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Symbicort_Turbohaler 200mcg/6mcg (120 D)',
#   'nic': 228.0,
#   'act_cost': 211.13,
#   'quantity': 6,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000K0BHAAAM',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'DuoResp Spiromax_Inh 160mcg/4.5mcg(120D)',
#   'nic': 119.88,
#   'act_cost': 111.03,
#   'quantity': 4,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000N0AAAYAY',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Fluticasone/Salmeterol_Inh 250/50mcg 60D',
#   'nic': 70.0,
#   'act_cost': 64.83,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0302000N0AAAZAZ',
# ...
#   'act_cost': 5.27,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000100',
#   'items': 32,
#   'practice': 'P85003',
#   'bnf_name': 'Epaderm Oint',
#   'nic': 204.77,
#   'act_cost': 189.96,
#   'quantity': 15000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000101',
#   'items': 5,
#   'practice': 'P85003',
#   'bnf_name': 'Epaderm Crm',
#   'nic': 34.75,
#   'act_cost': 32.23,
#   'quantity': 2500,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000111',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Flexitol Urea Heel Balm',
#   'nic': 6.55,
#   'act_cost': 6.09,
#   'quantity': 115,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000205',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Hydromol Oint',
#   'nic': 33.09,
#   'act_cost': 30.71,
#   'quantity': 2875,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000210',
#   'items': 35,
#   'practice': 'P85003',
#   'bnf_name': 'QV Crm',
#   'nic': 192.28,
#   'act_cost': 178.44,
#   'quantity': 15500,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000211',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'QV Gentle Wsh',
#   'nic': 3.17,
#   'act_cost': 2.95,
#   'quantity': 250,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000212',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'QV Intensive Oint',
#   'nic': 5.71,
#   'act_cost': 5.3,
#   'quantity': 450,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000233',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Cetraben Crm 50g',
#   'nic': 1.4,
#   'act_cost': 1.31,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000235',
#   'items': 21,
#   'practice': 'P85003',
#   'bnf_name': 'Cetraben Crm 500g',
#   'nic': 137.77,
#   'act_cost': 127.8,
#   'quantity': 23,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21220000240',
#   'items': 4,
#   'practice': 'P85003',
#   'bnf_name': 'Cetraben Oint 450g',
#   'nic': 48.51,
#   'act_cost': 44.95,
#   'quantity': 9,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21240000100',
#   'items': 10,
#   'practice': 'P85003',
#   'bnf_name': 'Orbis Nor Saline Sod Chlor 0.9% Nsl Dps',
#   'nic': 11.4,
#   'act_cost': 10.67,
#   'quantity': 12,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21240000105',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Mandanol Sod Chlor 0.9% Nsl Dps',
#   'nic': 1.98,
#   'act_cost': 1.85,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21240000120',
#   'items': 6,
#   'practice': 'P85003',
#   'bnf_name': 'Almus Sod Chlor 0.9% Nsl Dps',
#   'nic': 5.94,
#   'act_cost': 5.57,
#   'quantity': 6,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21240000160',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Sterimar Isotonic Nsl Spy 50ml',
#   'nic': 4.98,
#   'act_cost': 4.64,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21240000162',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Sterimar Baby Nsl Spy 50ml',
#   'nic': 2.49,
#   'act_cost': 2.32,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000104',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Hylo-Tear Sod Hyaluronate Eye Dps 0.1% P',
#   'nic': 8.5,
#   'act_cost': 7.88,
#   'quantity': 1,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000108',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Hyabak Sod Hyaluronate Eye Dps 10ml P/F',
#   'nic': 23.97,
#   'act_cost': 22.23,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000110',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Systane Hydroxypropyl Guar Eye Dps 10ml',
#   'nic': 9.32,
#   'act_cost': 8.65,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000111',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Hylo-Forte Sod Hyaluronate Eye Dps 0.2%',
#   'nic': 19.0,
#   'act_cost': 17.61,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000300',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Optive 0.5% Carmellose Eye Dps 10ml',
#   'nic': 14.98,
#   'act_cost': 13.89,
#   'quantity': 2,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000401',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'nic': 5.79,
#   'act_cost': 5.4,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000402',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Liquifilm 1.4% Polyvinyl Alcohol Eye Dps',
#   'nic': 5.35,
#   'act_cost': 4.97,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '21300000710',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Vita-POS Paraf Eye Oint P/F',
#   'nic': 2.75,
#   'act_cost': 2.56,
#   'quantity': 5,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '23800298002',
#   'items': 1,
#   'practice': 'P85003',
#   'bnf_name': 'Aspen_Sorbaderm No-Sting Barrier Film 1m',
#   'nic': 8.9,
#   'act_cost': 8.25,
#   'quantity': 10,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '23800298005',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': 'Aspen_Sorbaderm Barrier Crm 92g',
#   'nic': 28.76,
#   'act_cost': 26.65,
#   'quantity': 4,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '23802098001',
#   'items': 3,
#   'practice': 'P85003',
#   'bnf_name': 'H & R_Proshield Plus Skin Prote 115g',
#   'nic': 29.82,
#   'act_cost': 27.64,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '23803108006',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': '3m Health Care_Cavilon Durable Barrier C',
#   'nic': 24.36,
#   'act_cost': 22.58,
#   'quantity': 3,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '23803108009',
#   'items': 2,
#   'practice': 'P85003',
#   'bnf_name': '3m Health Care_Cavilon No Sting 3ml Barr',
#   'nic': 48.18,
#   'act_cost': 44.63,
#   'quantity': 6,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101010G0AAABAB',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#   'nic': 11.96,
#   'act_cost': 11.12,
#   'quantity': 2000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0AAALAL',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Sod Algin/Pot Bicarb_Susp S/F',
#   'nic': 14.33,
#   'act_cost': 13.61,
#   'quantity': 1400,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEADAJ',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Gaviscon Infant_Sach 2g (Dual Pack) S/F',
#   'nic': 57.84,
#   'act_cost': 53.59,
#   'quantity': 180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEAIAL',
#   'items': 16,
#   'practice': 'P85007',
#   'bnf_name': 'Gaviscon Advance_Liq (Aniseed) (Reckitt)',
#   'nic': 86.5,
#   'act_cost': 80.38,
#   'quantity': 8000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BEAQAP',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Gaviscon Advance_Tab Chble Mint(Reckitt)',
#   'nic': 6.14,
#   'act_cost': 5.71,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BIAAAH',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Peptac_Liq (Aniseed) S/F',
#   'nic': 5.85,
#   'act_cost': 5.45,
#   'quantity': 1500,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0101021B0BIABAH',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Peptac_Liq (Peppermint) S/F',
#   'nic': 3.9,
#   'act_cost': 3.64,
#   'quantity': 1000,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000A0AAABAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Alverine Cit_Cap 120mg',
#   'nic': 46.56,
#   'act_cost': 43.12,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000N0AAABAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Hyoscine Butylbrom_Tab 10mg',
#   'nic': 3.0,
#   'act_cost': 2.79,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000N0BBAAAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Buscopan_Tab 10mg',
#   'nic': 4.5,
#   'act_cost': 4.28,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000P0AAABAB',
#   'items': 11,
#   'practice': 'P85007',
#   'bnf_name': 'Mebeverine HCl_Tab 135mg',
#   'nic': 53.73,
#   'act_cost': 50.67,
#   'quantity': 1030,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0102000X0BCAAAA',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Fybogel Mebeverine_Eff Gran Sach S/F',
#   'nic': 55.68,
#   'act_cost': 51.58,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103010T0AAAAAA',
#   'items': 61,
#   'practice': 'P85007',
#   'bnf_name': 'Ranitidine HCl_Tab 150mg',
#   'nic': 60.21,
#   'act_cost': 59.1,
#   'quantity': 2912,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103010T0AAACAC',
#   'items': 8,
#   'practice': 'P85007',
#   'bnf_name': 'Ranitidine HCl_Tab 300mg',
#   'nic': 7.25,
#   'act_cost': 7.11,
#   'quantity': 171,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAAAAA',
#   'items': 9,
#   'practice': 'P85007',
#   'bnf_name': 'Esomeprazole_Tab E/C 20mg',
#   'nic': 22.55,
#   'act_cost': 21.49,
#   'quantity': 238,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050E0AAABAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Esomeprazole_Tab E/C 40mg',
#   'nic': 9.93,
#   'act_cost': 9.21,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAAAAA',
#   'items': 62,
#   'practice': 'P85007',
#   'bnf_name': 'Lansoprazole_Cap 30mg (E/C Gran)',
#   'nic': 63.86,
#   'act_cost': 61.19,
#   'quantity': 1610,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAABAB',
#   'items': 9,
#   'practice': 'P85007',
#   'bnf_name': 'Lansoprazole_Cap 15mg (E/C Gran)',
#   'nic': 9.24,
#   'act_cost': 8.67,
#   'quantity': 308,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050L0AAAHAH',
#   'items': 7,
#   'practice': 'P85007',
#   'bnf_name': 'Lansoprazole_Orodisper Tab 30mg',
#   'nic': 23.96,
#   'act_cost': 22.66,
#   'quantity': 196,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAAAA',
#   'items': 181,
#   'practice': 'P85007',
#   'bnf_name': 'Omeprazole_Cap E/C 20mg',
#   'nic': 192.48,
#   'act_cost': 184.34,
#   'quantity': 5919,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAEAE',
#   'items': 9,
#   'practice': 'P85007',
#   'bnf_name': 'Omeprazole_Cap E/C 40mg',
#   'nic': 27.0,
#   'act_cost': 25.1,
#   'quantity': 252,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAFAF',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Omeprazole_Cap E/C 10mg',
#   'nic': 2.67,
#   'act_cost': 2.51,
#   'quantity': 84,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AAAMAM',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Omeprazole_Tab Disper 10mg (E/C Pellets)',
#   'nic': 7.75,
#   'act_cost': 7.19,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050P0AABDBD',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Omeprazole_Tab E/C 20mg',
#   'nic': 24.04,
#   'act_cost': 22.29,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050R0AAABAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Pantoprazole_Tab E/C 20mg',
#   'nic': 0.95,
#   'act_cost': 0.89,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0103050T0AAABAB',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Rabeprazole Sod_Tab E/C 20mg',
#   'nic': 7.08,
#   'act_cost': 6.6,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0104020L0AAAAAA',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Loperamide HCl_Cap 2mg',
#   'nic': 6.4,
#   'act_cost': 6.04,
#   'quantity': 200,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010B0BBAAAA',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Asacol_MR Tab E/C 400mg',
#   'nic': 74.51,
#   'act_cost': 69.12,
#   'quantity': 228,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010B0BBAFAS',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Asacol_MR Tab E/C 800mg',
#   'nic': 109.8,
#   'act_cost': 101.66,
#   'quantity': 168,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010B0BIAAAS',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Octasa_MR Tab E/C 800mg',
#   'nic': 95.0,
#   'act_cost': 87.96,
#   'quantity': 180,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0105010E0AAAAAA',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Sulfasalazine_Tab 500mg',
#   'nic': 3.69,
#   'act_cost': 3.53,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106010E0AAADAD',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Ispag Husk_Gran Eff Sach 3.5g G/F S/F',
#   'nic': 8.16,
#   'act_cost': 7.58,
#   'quantity': 90,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106010E0BBABAH',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Fybogel_Gran Sach 3.5g Orange G/F S/F',
#   'nic': 2.72,
#   'act_cost': 2.53,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020I0AAAKAK',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Docusate Sod_Cap 100mg',
#   'nic': 6.97,
#   'act_cost': 6.56,
#   'quantity': 100,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020M0AAACAC',
#   'items': 20,
#   'practice': 'P85007',
#   'bnf_name': 'Senna_Tab 7.5mg',
#   'nic': 34.06,
#   'act_cost': 32.78,
#   'quantity': 1016,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106020M0AAATAT',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Senna_Oral Soln 7.5mg/5ml S/F',
#   'nic': 2.67,
#   'act_cost': 2.58,
#   'quantity': 280,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040G0AAAAAA',
#   'items': 25,
#   'practice': 'P85007',
#   'bnf_name': 'Lactulose_Soln 3.1g-3.7g/5ml',
#   'nic': 64.5,
#   'act_cost': 60.53,
#   'quantity': 12800,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0AAAAAA',
#   'items': 30,
#   'practice': 'P85007',
#   'bnf_name': 'Macrogol_Co Oral Pdr Sach S/F',
#   'nic': 183.06,
#   'act_cost': 171.14,
#   'quantity': 1286,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBAAAA',
#   'items': 5,
#   'practice': 'P85007',
#   'bnf_name': 'Movicol_Pdr Sach 13.8g (Lem & Lim)',
#   'nic': 77.2,
#   'act_cost': 71.53,
#   'quantity': 300,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBADAA',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Movicol Plain_Pdr Sach 13.7g',
#   'nic': 30.88,
#   'act_cost': 28.62,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106040M0BBAIAB',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Movicol Plain_Paed Pdr Sach 6.9g',
#   'nic': 17.52,
#   'act_cost': 16.27,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0106070B0AAAAAA',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Linaclotide_Cap 290mcg',
#   'nic': 37.56,
#   'act_cost': 34.78,
#   'quantity': 28,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020J0BEAAAE',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Proctosedyl_Oint',
#   'nic': 10.34,
#   'act_cost': 9.58,
#   'quantity': 30,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020P0BCAAAC',
#   'items': 4,
#   'practice': 'P85007',
#   'bnf_name': 'Scheriproct_Oint',
#   'nic': 11.76,
#   'act_cost': 10.94,
#   'quantity': 120,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0107020P0BCABAD',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Scheriproct_Suppos',
#   'nic': 4.14,
#   'act_cost': 3.87,
#   'quantity': 36,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0109010U0AAABAB',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Ursodeoxycholic Acid_Cap 250mg',
#   'nic': 47.21,
#   'act_cost': 43.82,
#   'quantity': 112,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0109040N0BDAGAY',
#   'items': 1,
#   'practice': 'P85007',
#   'bnf_name': 'Creon Micro_G/R Gran 100mg (60.36mg)',
#   'nic': 63.0,
#   'act_cost': 58.33,
#   'quantity': 40,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0201010F0AAADAD',
#   'items': 2,
#   'practice': 'P85007',
#   'bnf_name': 'Digoxin_Tab 62.5mcg',
#   'nic': 3.64,
#   'act_cost': 3.4,
#   'quantity': 56,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0201010F0AAAEAE',
#   'items': 12,
#   'practice': 'P85007',
#   'bnf_name': 'Digoxin_Tab 125mcg',
#   'nic': 23.66,
#   'act_cost': 22.05,
#   'quantity': 364,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010B0AAABAB',
#   'items': 51,
#   'practice': 'P85007',
#   'bnf_name': 'Bendroflumethiazide_Tab 2.5mg',
#   'nic': 39.67,
#   'act_cost': 37.86,
#   'quantity': 1682,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010P0AAAAAA',
#   'items': 8,
#   'practice': 'P85007',
#   'bnf_name': 'Indapamide_Tab 2.5mg',
#   'nic': 5.78,
#   'act_cost': 6.04,
#   'quantity': 151,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202010P0AAADAD',
#   'items': 3,
#   'practice': 'P85007',
#   'bnf_name': 'Indapamide_Tab 1.5mg M/R',
#   'nic': 9.97,
#   'act_cost': 9.37,
#   'quantity': 88,
#   'post_code': 'OL1 1NL'},
#  {'bnf_code': '0202020D0AAAEAE',
#   'items': 11,
#   'practice': 'P85007',
#   'bnf_name': 'Bumetanide_Tab 1mg',
#   'nic': 31.16,
#   'act_cost': 29.38,
#   'quantity': 532,
#   'post_code': 'OL1 1NL'},
#  ...]

# %%
items_by_post = [(pc[0],sum(group["items"] for group in groups
           )) for pc, groups in pc_grouped]

items_by_post = sorted(items_by_post)

# %%
items_by_post[:5]
# Out:
# [('B11 4BW', 20673),
#  ('B18 7AL', 19001),
#  ('B21 9RY', 29103),
#  ('B23 6DJ', 24859),
#  ('B70 7AW', 36531)]

# %% [markdown]
# Finally we'll group the prescription dictionaries in `joined` by `'post_code'` and sum up the items prescribed in each group, as we did in the previous question.

# %%
postal_totals = items_by_post[:100]

grader.score.pw__postal_totals(postal_totals)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# ## Question 4: items_by_region
#
# Now we'll combine the techniques we've developed to answer a more complex question. Find the most commonly dispensed item in each postal code, representing the results as a list of tuples (`post_code`, `bnf_name`, amount dispensed as proportion of total). Sort your results ascending alphabetically by post code and take only results from the first 100 post codes.
#
# **NOTE:** We'll continue to use the `joined` variable we created before, where we've chosen the alphabetically first postal code for each practice. Additionally, some postal codes will have multiple `'bnf_name'` with the same number of items prescribed for the maximum. In this case, we'll take the alphabetically first `'bnf_name'`.

# %% [markdown]
# Now we need to calculate the total items of each `'bnf_name'` prescribed in each `'post_code'`. Use the techniques we developed in the previous questions to calculate these totals. You should have 141196 `('post_code', 'bnf_name')` groups.

# %%
scripts[0]
# Out:
# {'bnf_code': '0101010G0AAABAB',
#  'items': 2,
#  'practice': 'N81013',
#  'bnf_name': 'Co-Magaldrox_Susp 195mg/220mg/5ml S/F',
#  'nic': 5.98,
#  'act_cost': 5.56,
#  'quantity': 1000,
#  'post_code': 'SK11 6JL'}

# %%
name_grouped = list(group_by_field(joined, ("post_code", "bnf_name")).items())

# %%
name_grouped[0]
# Out:
# (('CW5 5NX', 'Capasal_Therapeutic Shampoo'),
#  [{'bnf_code': '1309000C0BLAAAQ',
#    'items': 4,
#    'practice': 'N81047',
#    'bnf_name': 'Capasal_Therapeutic Shampoo',
#    'nic': 18.76,
#    'act_cost': 17.4,
#    'quantity': 1000,
#    'post_code': 'CW5 5NX'},
#   {'bnf_code': '1309000C0BLAAAQ',
#    'items': 2,
#    'practice': 'N81090',
#    'bnf_name': 'Capasal_Therapeutic Shampoo',
#    'nic': 9.38,
#    'act_cost': 8.71,
#    'quantity': 500,
#    'post_code': 'CW5 5NX'}])

# %%
total_items_by_bnf_post = {name: sum(group["items"] for group in groups) for name,groups in name_grouped}

# %%
assert len(total_items_by_bnf_post) == 141196

# %%
list(total_items_by_bnf_post.items())[:5]
# Out:
# [(('CW5 5NX', 'Capasal_Therapeutic Shampoo'), 6),
#  (('CB9 8HF', 'Timoptol_Eye Dps 0.25% W/V'), 2),
#  (('BD3 8QH', 'Zineryt_Lot'), 2),
#  (('SK11 6JL', 'Co-Codamol_Cap 30mg/500mg'), 29),
#  (('M26 2SP', 'Pivmecillinam HCl_Tab 200mg'), 39)]

# %%
total_items = [{"post_code":tup[0], "bnf_name":tup[1], "total":tot} 
 for tup,tot in list(total_items_by_bnf_post.items())[:]]

# %%
total_items[0]
# Out:
# {'post_code': 'CW5 5NX', 'bnf_name': 'Capasal_Therapeutic Shampoo', 'total': 6}

# %%
total_items_by_post = group_by_field(total_items, ("post_code",))

# %% [markdown]
# Let's use `total_items` to find the maximum item total for each postal code. To do this, we will want to regroup `total_items_by_bnf_post` by `'post_code'` only, not by `('post_code', 'bnf_name')`. First let's turn `total_items` into a list of dictionaries (similar to `scripts` or `practices`) and then group it by `'post_code'`. You should have 118 groups in the resulting `total_items_by_post` after grouping `total_items` by `'post_code'`.

# %%
assert len(total_items_by_post) == 118

# %% [markdown]
# Now we will aggregate the groups in `total_by_item_post` to create `max_item_by_post`. Some `'bnf_name'` have the same item total within a given postal code. Therefore, if more than one `'bnf_name'` has the maximum item total in a given postal code, we'll take the alphabetically first `'bnf_name'`. We can do this by [sorting](https://docs.python.org/2.7/howto/sorting.html) each group according to the item total and `'bnf_name'`.

# %%
test_list = total_items_by_post[("B18 7AL",)]

# %%
test_list[:5]
# Out:
# [{'post_code': 'B18 7AL',
#   'bnf_name': 'Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#   'total': 9},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#   'total': 8},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Fortini_Multi Fibre Liq (4 Flav)',
#   'total': 3},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#   'total': 2},
#  {'post_code': 'B18 7AL', 'bnf_name': 'Sertraline HCl_Tab 50mg', 'total': 72}]

# %%
sorted(test_list[:5],
       key = lambda mem:(-mem['total'], mem["bnf_name"]))
# Out:
# [{'post_code': 'B18 7AL', 'bnf_name': 'Sertraline HCl_Tab 50mg', 'total': 72},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Fluticasone Prop_Nsl Spy 50mcg (150 D)',
#   'total': 9},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Beclomet Diprop_Inha 100mcg (200 D) CFF',
#   'total': 8},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Fortini_Multi Fibre Liq (4 Flav)',
#   'total': 3},
#  {'post_code': 'B18 7AL',
#   'bnf_name': 'Seebri_Breezhaler Inh Cap 55mcg + Dev',
#   'total': 2}]

# %%
max_item_by_post = [sorted(group,
       key = lambda mem:(-mem['total'], mem["bnf_name"]))[0]
for group in total_items_by_post.values()]

# %%
result =[(item["post_code"],
  item["bnf_name"],
    item["total"] / dict(items_by_post)[item["post_code"]]) 
for item in max_item_by_post]

# %%
sorted(result)[:10]
# Out:
# [('B11 4BW', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.03415082474725487),
#  ('B18 7AL', 'Salbutamol_Inha 100mcg (200 D) CFF', 0.02926161780958897),
#  ('B21 9RY', 'Metformin HCl_Tab 500mg', 0.03549462254750369),
#  ('B23 6DJ', 'Lansoprazole_Cap 30mg (E/C Gran)', 0.024095900880968663),
#  ('B70 7AW', 'Paracet_Tab 500mg', 0.0266896608360023),
#  ('BB11 2DL', 'Omeprazole_Cap E/C 20mg', 0.02884503434625684),
#  ('BB2 1AX', 'Omeprazole_Cap E/C 20mg', 0.03645501521908402),
#  ('BB3 1PY', 'Omeprazole_Cap E/C 20mg', 0.03428477088454342),
#  ('BB4 5SL', 'Omeprazole_Cap E/C 20mg', 0.040696883081529876),
#  ('BB7 2JG', 'Omeprazole_Cap E/C 20mg', 0.029471795446899183)]

# %% [markdown]
# In order to express the item totals as a proportion of the total amount of items prescribed across all `'bnf_name'` in a postal code, we'll need to use the total items prescribed that we previously calculated as `items_by_post`. Calculate the proportions for the most common `'bnf_names'` for each postal code. Format your answer as a list of tuples: `[(post_code, bnf_name, total)]`

# %%
items_by_region = sorted(result)[:100]

# %%
grader.score.pw__items_by_region(items_by_region)
# Out:
# ==================
# Your score:  1.0
# ==================

# %% [markdown]
# *Copyright &copy; 2020 The Data Incubator.  All rights reserved.*
